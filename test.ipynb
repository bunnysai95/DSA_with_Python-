# %%
name = "alex"
typed = "aaleex"   

i = j = 0 

while i < len(name) and j < len(typed):
    if name[i] == typed[j]:
        i +=1
    elif j ==0 or typed[j] != typed[j-1]:
        print(False)
    j +=1 

print(i == len(name))
# Out:
# True
